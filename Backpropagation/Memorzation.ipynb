# %%
import numpy as np

def fib(n):
    if n==1 or n==0:
        return n
    else:
        return fib(n-1) + fib(n-2)

# %%
fib(10)
# Out:
# 55

# %%
def fib_update(n,d):
    if n in d:
        return d[n]
    else:
        d[n] = fib_update(n-1,d) + fib_update(n-2,d)
        return d[n]

d = {0:1,1:1}
fib_update(10,d)
# Out:
# 89
