# %%
# L=-yi logyi^+ (1-yi) log(1-yi)^

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

def binary_cross_entropy(y_true, y_pred):
    # Make sure predictions are clipped between 0 and 1
    y_pred = np.clip(y_pred, 1e-15, 1 - 1e-15)
    # BCE formula
    loss = -(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
    return np.mean(loss)

# Example:
y_true = np.array([1, 0, 1, 0])      # Actual labels
y_pred = np.array([0.9, 0.2, 0.8, 0.1])  # Predicted probabilities

loss = binary_cross_entropy(y_true, y_pred)
print(f"Binary Cross Entropy Loss: {loss}")
# Out:
# Binary Cross Entropy Loss: 0.16425203348601802

# %%
from sklearn.datasets import make_classification
import numpy as np

# Generate a dataset with 100 samples and 2 features (binary classification)
X, y = make_classification(n_samples=100, n_features=2, n_informative=2, 
                           n_redundant=0, n_clusters_per_class=1, random_state=42)

# Define binary cross-entropy function
def binary_cross_entropy(y_true, y_pred, epsilon=1e-15):
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
    return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))

# Example: calculate BCE with synthetic predictions (assume perfect classifier for demonstration)
y_pred = y.astype(float)  # Perfect predictions: 1 where y=1, 0 where y=0
bce = binary_cross_entropy(y, y_pred)

bce
# Out:
# 9.992007221626413e-16

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of the dataset
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', edgecolor='k', s=60)
plt.title("Binary Classification Dataset (2D)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend(*scatter.legend_elements(), title="Class")
plt.grid(True)
plt.tight_layout()
plt.show()
