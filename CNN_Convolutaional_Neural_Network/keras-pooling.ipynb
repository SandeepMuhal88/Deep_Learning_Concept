# %%
# %pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (1.72.1)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\programming\deep_learning\deep_learning_concept\.deeplr\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow 
from tensorflow import keras
from keras.layers import Dense, Flatten,Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
model= Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='valid'))
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='valid'))
model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# d:\Programming\Deep_Learning\Deep_Learning_Concept\.deeplr\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       102,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 113,386 (442.91 KB)
#  Trainable params: 113,386 (442.91 KB)
#  Non-trainable params: 0 (0.00 B)
