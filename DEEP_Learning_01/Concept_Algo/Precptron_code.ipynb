# %%
# A Perceptron is the simplest neural unit that tries to classify data into two categories (binary classification).

# z=w.x + b
# If z >= 0, output = 1
# x = input vector
# w = weights
# b = bias
# Activation = Step Function (hard threshold)
